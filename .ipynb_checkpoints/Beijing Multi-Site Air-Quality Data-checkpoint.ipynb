# %% [markdown]
# ## Beijing Multi-Site Air-Quality Data

# %% [markdown]
# ### Importing the modules

# %% [markdown]
# In this section all the needed modules are being added. As the project evolves, this section will be updated.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import datetime as dt

from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

from sklearn.metrics import mean_squared_error,mean_absolute_error

import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from statsmodels.tsa.ar_model import AR, ARResults

from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# ## Dataset

# %% [markdown]
# The first step in working with datasets that are downloaded for the purpose of learning involves understanding the data and ensuring that the data is apropriate for the this purpose.
# In this section, general characteristics of the dataset are being investigated.

# %%
## Loading the data
df=pd.read_csv("C:/SharpestMinds/Datasets/D12- Beijing Multi-Site Air-Quality Data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")

# %%
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# std       82.135694     95.223005     22.823017     37.116200   1221.436236
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     30.000000    500.000000
# 50%       58.000000     87.000000      9.000000     53.000000    900.000000
# 75%      114.000000    155.000000     21.000000     82.000000   1500.000000
# max      898.000000    984.000000    341.000000    290.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33345.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      56.353358     13.584607   1011.846920      3.123062      0.067421
# std       57.916327     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        8.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       42.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       82.000000     23.300000   1020.100000     15.600000      0.000000
# max      423.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000

# %%
## Creating a timestamp index from columns containing the time elements
df['Time']=pd.to_datetime(df[['year', 'month', 'day', 'hour']])
df.index = df['Time']

# %%
## Adding a new column to identify the day of the week and dropping wxtra columns
df['weekday']=df['Time'].dt.day_name()
df.drop(['No', 'year', 'month', 'day', 'hour', 'Time', 'wd'], axis=1, inplace=True)

# %% [markdown]
# ### Resampling the data

# %% [markdown]
# Considering the resolution of the data and the purpose of this project, it is helpful to aggregate the data to a higher level. In this step the data is sampled down to daily data points. Maximum, average, and min values of the measurements are included according to their meaning.
# https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf

# %%
dfrs = df.resample(rule='D').agg({'PM2.5': "max", "PM10": "max", "SO2": "max", "NO2": "max", "CO": "max", "O3": "max", "TEMP": ["max", "mean", "min"], "PRES": "mean", "DEWP":"mean", "RAIN": "sum", "WSPM": "mean"})
dfrs.columns = ["_".join(a) for a in dfrs.columns.to_flat_index()]
dfrs.head()
# Out:
#             PM2.5_max  PM10_max  SO2_max  NO2_max  CO_max  O3_max  TEMP_max  \
# Time
# 2013-03-01       24.0      24.0     26.0     57.0   700.0    77.0       6.2
# 2013-03-02       93.0     120.0     87.0    110.0  1700.0    52.0       3.9
# 2013-03-03      117.0     181.0    135.0    135.0  2799.0    77.0      16.9
# 2013-03-04       58.0      94.0     51.0     86.0  1300.0    84.0      15.3
# 2013-03-05      226.0     269.0    147.0    204.0  4400.0    84.0      13.8
#
#             TEMP_mean  TEMP_min    PRES_mean  DEWP_mean  RAIN_sum  WSPM_mean
# Time
# 2013-03-01   1.391667      -2.6  1026.875000 -18.745833       0.0   3.254167
# 2013-03-02   0.616667      -2.5  1026.850000 -15.937500       0.0   1.479167
# 2013-03-03   5.566667      -5.8  1014.608333 -12.316667       0.0   1.658333
# 2013-03-04   9.962500       2.7  1017.650000 -11.683333       0.0   2.404167
# 2013-03-05   6.291667      -0.6  1010.900000  -7.525000       0.0   1.129167

# %%
dfrs['TEMP_max'].plot()
dfrs['TEMP_min'].plot()
dfrs['TEMP_mean'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# ### Choosing data elements to focus on

# %%
dfrsTEMP = dfrs[['TEMP_max', 'TEMP_mean', 'TEMP_min']]
dfrsTEMP.head()
# Out:
#             TEMP_max  TEMP_mean  TEMP_min
# Time
# 2013-03-01       6.2   1.391667      -2.6
# 2013-03-02       3.9   0.616667      -2.5
# 2013-03-03      16.9   5.566667      -5.8
# 2013-03-04      15.3   9.962500       2.7
# 2013-03-05      13.8   6.291667      -0.6

# %% [markdown]
# ### ETS Decomposition

# %%
ETSTEMP = seasonal_decompose(dfrsTEMP['TEMP_mean'], model='additive')

# %%
rcParams['figure.figsize'] = 12, 5
ETSTEMP.plot();

# %% [markdown]
# The results of the decomposition above indicates that we need to use an additive model for forcasting the temperature avriable.

# %%
ETSTEMPw = seasonal_decompose(dfrsTEMP['TEMP_mean'].resample(rule='W').mean(), model='additive')
rcParams['figure.figsize'] = 12, 5
ETSTEMPw.plot();

# %% [markdown]
# ### Stationarity

# %% [markdown]
# Visual inspection of the data shows its non-stationary characteristic. We can also test its stationarity using the Augmented Dickey-Fuller test.

# %%
## Stationarity test using ad-fuller method
STTTEMP = adfuller(dfrsTEMP['TEMP_mean'])
print('ADF Statistic: %f' % STTTEMP[0])
print('p-value: %f' % STTTEMP[1])
print('Critical Values:')
for key, value in STTTEMP[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.151773
# p-value: 0.224212
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# According to the outcome o of the ADF test which is over 5% we reject the null hypothesis and conclude that the data is non-stationary.

# %% [markdown]
# ### MA - Simple Moving Average

# %%
dfrsTEMP['TEMP_mean_MA_7'] = dfrsTEMP['TEMP_mean'].rolling(window=7).mean()
dfrsTEMP[['TEMP_mean', 'TEMP_mean_MA_7']][:'2013-09-01'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# ### Exponentially Weighted Moving Average

# %%
dfrsTEMP['TEMP_mean_EWMA_7'] = dfrsTEMP['TEMP_mean'].ewm(span=7).mean()
dfrsTEMP[['TEMP_mean', 'TEMP_mean_MA_7', 'TEMP_mean_EWMA_7']][:'2013-09-01'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
## StatsModels provides a function that can give us the same outcome.
dfrsTEMP['TEMP_mean_SES_7']=SimpleExpSmoothing(dfrsTEMP['TEMP_mean']).fit(smoothing_level=(2/(7+1)),optimized=False).fittedvalues.shift(-1)
dfrsTEMP[['TEMP_mean_EWMA_7','TEMP_mean_SES_7']][:'2013-09-01'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# Now we are going to add the second layer of smoothing which is the trend. As concluded above, this data

# %%
dfrsTEMP['TEMP_mean_DES_7']=ExponentialSmoothing(dfrsTEMP['TEMP_mean'],trend='add').fit().fittedvalues.shift(-1)
dfrsTEMP[['TEMP_mean', 'TEMP_mean_MA_7', 'TEMP_mean_SES_7', 'TEMP_mean_DES_7']][:'2013-09-01'].plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# Here we add the seasonality as the third level of smoothing.

# %%
dfrsTEMP['TEMP_mean_TES_7']=ExponentialSmoothing(dfrsTEMP['TEMP_mean'],trend='add', seasonal='add', seasonal_periods=365).fit().fittedvalues.shift(-1)
dfrsTEMP[['TEMP_mean','TEMP_mean_DES_7','TEMP_mean_TES_7']].iloc[:20].plot()
dfrsTEMP[['TEMP_mean','TEMP_mean_DES_7','TEMP_mean_TES_7']].iloc[-20:].plot()
# Out:
# C:\Users\iraj2\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# ### Forecasting

# %% [markdown]
# In this step we build a simple forcasting model based on the Exponential Weighted Moving average above

# %% [markdown]
# ##### Train the Model

# %%
## Creating the train and test datasets
dfrsTEMPtrain = dfrsTEMP[:'2016-03-01']
dfrsTEMPtest = dfrsTEMP['2016-03-01':]

# %%
## Fitting a model on the training dataset
TES_TEMP_fitted = ExponentialSmoothing(dfrsTEMPtrain['TEMP_mean'],
                                      #trend='add',
                                      seasonal='add',
                                      seasonal_periods=365).fit()

# %%
TES_TEMP_pred = TES_TEMP_fitted.forecast(365)

# %%
## Plot the train, test, and fitted model datasets
dfrsTEMPtrain['TEMP_mean'].plot(legend=True,label='TRAIN',figsize=(15,8))
dfrsTEMPtest['TEMP_mean'].plot(legend=True,label='TEST')
TES_TEMP_pred.plot(legend=True,label='PREDICTION',xlim=['2015-03-01','2016-12-01'])
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# ##### Evaluating Forecast Prediction

# %%
dfrsTEMPtest['TEMP_mean'].describe()
# Out:
# count    365.000000
# mean      14.289984
# std       10.859957
# min       -5.095833
# 25%        3.275000
# 50%       15.488542
# 75%       24.675000
# max       32.079167
# Name: TEMP_mean, dtype: float64

# %%
print(f"Mean Absolute Error: {mean_absolute_error(dfrsTEMPtest['TEMP_mean'],TES_TEMP_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(dfrsTEMPtest['TEMP_mean'],TES_TEMP_pred))}")
# Out:
# Mean Absolute Error: 2.7950865680138905
# Root Mean Squared Error: 3.324252254393885

# %% [markdown]
# ##### Prediction

# %%
## Train the model with the whole dataset
TEMP_forecast_model = ExponentialSmoothing(dfrsTEMP['TEMP_mean'],
                                      trend='add',
                                      seasonal='add',
                                      seasonal_periods=365).fit()

# %%
TEMP_forecast_prediction = TEMP_forecast_model.forecast(365)

# %%
## Plot the original data and prediction
dfrsTEMP['TEMP_mean'].plot(figsize=(12,8))
TEMP_forecast_prediction.plot()
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# ### ACF and PACF

# %% [markdown]
# Auto Correlation Function (ACF) and Partial Auto Correlation Function (PACF) are basically evaluating how much the values in a time series is related to it's previous values. They are used to figure the parameters used in prediction models.

# %%
lag_plot(dfrsTEMP['TEMP_mean'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
plot_acf(dfrsTEMP['TEMP_mean'], lags=365);

# %%
plot_pacf(dfrsTEMP['TEMP_mean'], lags=365);

# %% [markdown]
# ### AR models

# %%
TEMP_AR_model = AR(dfrsTEMPtrain['TEMP_mean'])

# %%
TEMP_AR_model = AR(dfrsTEMPtrain['TEMP_mean'])
TEMP_AR_model_fit_1 =TEMP_AR_model.fit(maxlag=1)
TEMP_AR_model_fit_1_PRED = TEMP_AR_model_fit_1.predict(start=len(dfrsTEMPtrain),end=len(dfrsTEMPtrain)+len(dfrsTEMPtest)+1)
TEMP_AR_model_fit_1_PRED = TEMP_AR_model_fit_1_PRED.rename('AR(1) Predictions')
dfrsTEMPtrain['TEMP_mean'].plot(legend=True,label='TRAIN',figsize=(15,8))
dfrsTEMPtest['TEMP_mean'].plot(legend=True,label='TEST')
TEMP_AR_model_fit_1_PRED.plot(legend=True,xlim=['2015-03-01','2016-12-01'])
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
TEMP_AR_model = AR(dfrsTEMPtrain['TEMP_mean'])
TEMP_AR_model_fit_2 =TEMP_AR_model.fit(maxlag=2)
TEMP_AR_model_fit_2_PRED = TEMP_AR_model_fit_2.predict(start=len(dfrsTEMPtrain),end=len(dfrsTEMPtrain)+len(dfrsTEMPtest)+1)
TEMP_AR_model_fit_2_PRED = TEMP_AR_model_fit_2_PRED.rename('AR(2) Predictions')
dfrsTEMPtrain['TEMP_mean'].plot(legend=True,label='TRAIN',figsize=(15,8))
dfrsTEMPtest['TEMP_mean'].plot(legend=True,label='TEST')
TEMP_AR_model_fit_2_PRED.plot(legend=True,xlim=['2015-03-01','2016-12-01'])
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
TEMP_AR_model = AR(dfrsTEMPtrain['TEMP_mean'])
TEMP_AR_model_fit_ic =TEMP_AR_model.fit(ic='t-stat')
TEMP_AR_model_fit_ic_PRED = TEMP_AR_model_fit_ic.predict(start=len(dfrsTEMPtrain),end=len(dfrsTEMPtrain)+len(dfrsTEMPtest)+1)
TEMP_AR_model_fit_ic_PRED = TEMP_AR_model_fit_ic_PRED.rename('AR(ic) Predictions')
dfrsTEMPtrain['TEMP_mean'].plot(legend=True,label='TRAIN',figsize=(15,8))
dfrsTEMPtest['TEMP_mean'].plot(legend=True,label='TEST')
TEMP_AR_model_fit_ic_PRED.plot(legend=True,xlim=['2016-01-01','2016-05-01'])
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
TEMP_AR_model_fit_ic.params
# Out:
# const            0.106919
# L1.TEMP_mean     0.846207
# L2.TEMP_mean    -0.143446
# L3.TEMP_mean     0.106356
# L4.TEMP_mean     0.040423
# L5.TEMP_mean     0.121668
# L6.TEMP_mean    -0.017642
# L7.TEMP_mean     0.045671
# L8.TEMP_mean    -0.053503
# L9.TEMP_mean     0.070784
# L10.TEMP_mean   -0.075952
# L11.TEMP_mean    0.050964
# dtype: float64

# %%
TEMP_AR_model = AR(dfrsTEMPtrain['TEMP_mean'])
TEMP_AR_model_fit =TEMP_AR_model.fit()
TEMP_AR_model_fit_PRED = TEMP_AR_model_fit_ic.predict(start=len(dfrsTEMPtrain),end=len(dfrsTEMPtrain)+len(dfrsTEMPtest)+1)
TEMP_AR_model_fit_PRED = TEMP_AR_model_fit_ic_PRED.rename('AR() Predictions')
dfrsTEMPtrain['TEMP_mean'].plot(legend=True,label='TRAIN',figsize=(15,8))
dfrsTEMPtest['TEMP_mean'].plot(legend=True,label='TEST')
TEMP_AR_model_fit_ic_PRED.plot(legend=True,xlim=['2016-01-01','2016-05-01'])
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
TEMP_AR_model_fit.params
# Out:
# const            0.126352
# L1.TEMP_mean     0.842179
# L2.TEMP_mean    -0.141056
# L3.TEMP_mean     0.115934
# L4.TEMP_mean     0.036266
# L5.TEMP_mean     0.123319
# L6.TEMP_mean    -0.019865
# L7.TEMP_mean     0.047942
# L8.TEMP_mean    -0.058453
# L9.TEMP_mean     0.071345
# L10.TEMP_mean   -0.085782
# L11.TEMP_mean    0.078396
# L12.TEMP_mean   -0.032284
# L13.TEMP_mean    0.022574
# L14.TEMP_mean    0.000711
# L15.TEMP_mean    0.042935
# L16.TEMP_mean   -0.024438
# L17.TEMP_mean    0.002325
# L18.TEMP_mean   -0.035622
# L19.TEMP_mean    0.039513
# L20.TEMP_mean   -0.048472
# L21.TEMP_mean    0.035353
# L22.TEMP_mean   -0.022430
# dtype: float64

# %% [markdown]
# ### Granger Causality Test

# %% [markdown]
# Granger Causality Test is used to see if any other time series is affecting our data changes.
# For this purpose we first plot other variables of our dataset and choose one to perform the test with.

# %%
dfrs.plot(y=['TEMP_mean', 'PRES_mean', 'DEWP_mean', 'RAIN_sum', 'WSPM_mean'], figsize=(12,8));
dfrs.plot(y=['TEMP_mean', 'DEWP_mean', 'WSPM_mean'], figsize=(12,8));

# %%
grangercausalitytests(dfrs[['TEMP_mean', 'DEWP_mean']], maxlag=15);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=53.7580 , p=0.0000  , df_denom=1457, df_num=1
# ssr based chi2 test:   chi2=53.8687 , p=0.0000  , df=1
# likelihood ratio test: chi2=52.8987 , p=0.0000  , df=1
# parameter F test:         F=53.7580 , p=0.0000  , df_denom=1457, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=68.7894 , p=0.0000  , df_denom=1454, df_num=2
# ssr based chi2 test:   chi2=138.0520, p=0.0000  , df=2
# likelihood ratio test: chi2=131.9055, p=0.0000  , df=2
# parameter F test:         F=68.7894 , p=0.0000  , df_denom=1454, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=46.7227 , p=0.0000  , df_denom=1451, df_num=3
# ssr based chi2 test:   chi2=140.8443, p=0.0000  , df=3
# likelihood ratio test: chi2=134.4501, p=0.0000  , df=3
# parameter F test:         F=46.7227 , p=0.0000  , df_denom=1451, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=35.4219 , p=0.0000  , df_denom=1448, df_num=4
# ssr based chi2 test:   chi2=142.5682, p=0.0000  , df=4
# likelihood ratio test: chi2=136.0170, p=0.0000  , df=4
# parameter F test:         F=35.4219 , p=0.0000  , df_denom=1448, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=29.2651 , p=0.0000  , df_denom=1445, df_num=5
# ssr based chi2 test:   chi2=147.4393, p=0.0000  , df=5
# likelihood ratio test: chi2=140.4428, p=0.0000  , df=5
# parameter F test:         F=29.2651 , p=0.0000  , df_denom=1445, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=24.8387 , p=0.0000  , df_denom=1442, df_num=6
# ssr based chi2 test:   chi2=150.3757, p=0.0000  , df=6
# likelihood ratio test: chi2=143.1020, p=0.0000  , df=6
# parameter F test:         F=24.8387 , p=0.0000  , df_denom=1442, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=21.8768 , p=0.0000  , df_denom=1439, df_num=7
# ssr based chi2 test:   chi2=154.7339, p=0.0000  , df=7
# likelihood ratio test: chi2=147.0417, p=0.0000  , df=7
# parameter F test:         F=21.8768 , p=0.0000  , df_denom=1439, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=19.1971 , p=0.0000  , df_denom=1436, df_num=8
# ssr based chi2 test:   chi2=155.3950, p=0.0000  , df=8
# likelihood ratio test: chi2=147.6341, p=0.0000  , df=8
# parameter F test:         F=19.1971 , p=0.0000  , df_denom=1436, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=17.1294 , p=0.0000  , df_denom=1433, df_num=9
# ssr based chi2 test:   chi2=156.2083, p=0.0000  , df=9
# likelihood ratio test: chi2=148.3636, p=0.0000  , df=9
# parameter F test:         F=17.1294 , p=0.0000  , df_denom=1433, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.6095 , p=0.0000  , df_denom=1430, df_num=10
# ssr based chi2 test:   chi2=158.3869, p=0.0000  , df=10
# likelihood ratio test: chi2=150.3240, p=0.0000  , df=10
# parameter F test:         F=15.6095 , p=0.0000  , df_denom=1430, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=14.2370 , p=0.0000  , df_denom=1427, df_num=11
# ssr based chi2 test:   chi2=159.1307, p=0.0000  , df=11
# likelihood ratio test: chi2=150.9892, p=0.0000  , df=11
# parameter F test:         F=14.2370 , p=0.0000  , df_denom=1427, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=13.4792 , p=0.0000  , df_denom=1424, df_num=12
# ssr based chi2 test:   chi2=164.5898, p=0.0000  , df=12
# likelihood ratio test: chi2=155.8946, p=0.0000  , df=12
# parameter F test:         F=13.4792 , p=0.0000  , df_denom=1424, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=12.6839 , p=0.0000  , df_denom=1421, df_num=13
# ssr based chi2 test:   chi2=168.0233, p=0.0000  , df=13
# likelihood ratio test: chi2=158.9688, p=0.0000  , df=13
# parameter F test:         F=12.6839 , p=0.0000  , df_denom=1421, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=11.7528 , p=0.0000  , df_denom=1418, df_num=14
# ssr based chi2 test:   chi2=167.9049, p=0.0000  , df=14
# likelihood ratio test: chi2=158.8569, p=0.0000  , df=14
# parameter F test:         F=11.7528 , p=0.0000  , df_denom=1418, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=11.0048 , p=0.0000  , df_denom=1415, df_num=15
# ssr based chi2 test:   chi2=168.6891, p=0.0000  , df=15
# likelihood ratio test: chi2=159.5536, p=0.0000  , df=15
# parameter F test:         F=11.0048 , p=0.0000  , df_denom=1415, df_num=15

# %%
grangercausalitytests(dfrs[['TEMP_mean', 'WSPM_mean']], maxlag=15);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=62.1862 , p=0.0000  , df_denom=1457, df_num=1
# ssr based chi2 test:   chi2=62.3142 , p=0.0000  , df=1
# likelihood ratio test: chi2=61.0211 , p=0.0000  , df=1
# parameter F test:         F=62.1862 , p=0.0000  , df_denom=1457, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=65.4904 , p=0.0000  , df_denom=1454, df_num=2
# ssr based chi2 test:   chi2=131.4311, p=0.0000  , df=2
# likelihood ratio test: chi2=125.8444, p=0.0000  , df=2
# parameter F test:         F=65.4904 , p=0.0000  , df_denom=1454, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=42.8388 , p=0.0000  , df_denom=1451, df_num=3
# ssr based chi2 test:   chi2=129.1363, p=0.0000  , df=3
# likelihood ratio test: chi2=123.7342, p=0.0000  , df=3
# parameter F test:         F=42.8388 , p=0.0000  , df_denom=1451, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=32.8885 , p=0.0000  , df_denom=1448, df_num=4
# ssr based chi2 test:   chi2=132.3718, p=0.0000  , df=4
# likelihood ratio test: chi2=126.6997, p=0.0000  , df=4
# parameter F test:         F=32.8885 , p=0.0000  , df_denom=1448, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=26.7250 , p=0.0000  , df_denom=1445, df_num=5
# ssr based chi2 test:   chi2=134.6421, p=0.0000  , df=5
# likelihood ratio test: chi2=128.7756, p=0.0000  , df=5
# parameter F test:         F=26.7250 , p=0.0000  , df_denom=1445, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=22.4662 , p=0.0000  , df_denom=1442, df_num=6
# ssr based chi2 test:   chi2=136.0127, p=0.0000  , df=6
# likelihood ratio test: chi2=130.0258, p=0.0000  , df=6
# parameter F test:         F=22.4662 , p=0.0000  , df_denom=1442, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=20.0382 , p=0.0000  , df_denom=1439, df_num=7
# ssr based chi2 test:   chi2=141.7299, p=0.0000  , df=7
# likelihood ratio test: chi2=135.2407, p=0.0000  , df=7
# parameter F test:         F=20.0382 , p=0.0000  , df_denom=1439, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=19.1606 , p=0.0000  , df_denom=1436, df_num=8
# ssr based chi2 test:   chi2=155.0991, p=0.0000  , df=8
# likelihood ratio test: chi2=147.3668, p=0.0000  , df=8
# parameter F test:         F=19.1606 , p=0.0000  , df_denom=1436, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=16.9691 , p=0.0000  , df_denom=1433, df_num=9
# ssr based chi2 test:   chi2=154.7471, p=0.0000  , df=9
# likelihood ratio test: chi2=147.0437, p=0.0000  , df=9
# parameter F test:         F=16.9691 , p=0.0000  , df_denom=1433, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=15.1744 , p=0.0000  , df_denom=1430, df_num=10
# ssr based chi2 test:   chi2=153.9727, p=0.0000  , df=10
# likelihood ratio test: chi2=146.3388, p=0.0000  , df=10
# parameter F test:         F=15.1744 , p=0.0000  , df_denom=1430, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=14.0558 , p=0.0000  , df_denom=1427, df_num=11
# ssr based chi2 test:   chi2=157.1063, p=0.0000  , df=11
# likelihood ratio test: chi2=149.1639, p=0.0000  , df=11
# parameter F test:         F=14.0558 , p=0.0000  , df_denom=1427, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=13.2850 , p=0.0000  , df_denom=1424, df_num=12
# ssr based chi2 test:   chi2=162.2183, p=0.0000  , df=12
# likelihood ratio test: chi2=153.7634, p=0.0000  , df=12
# parameter F test:         F=13.2850 , p=0.0000  , df_denom=1424, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=12.6089 , p=0.0000  , df_denom=1421, df_num=13
# ssr based chi2 test:   chi2=167.0300, p=0.0000  , df=13
# likelihood ratio test: chi2=158.0785, p=0.0000  , df=13
# parameter F test:         F=12.6089 , p=0.0000  , df_denom=1421, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=11.8095 , p=0.0000  , df_denom=1418, df_num=14
# ssr based chi2 test:   chi2=168.7138, p=0.0000  , df=14
# likelihood ratio test: chi2=159.5816, p=0.0000  , df=14
# parameter F test:         F=11.8095 , p=0.0000  , df_denom=1418, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=11.1169 , p=0.0000  , df_denom=1415, df_num=15
# ssr based chi2 test:   chi2=170.4067, p=0.0000  , df=15
# likelihood ratio test: chi2=161.0909, p=0.0000  , df=15
# parameter F test:         F=11.1169 , p=0.0000  , df_denom=1415, df_num=15

# %%
grangercausalitytests(dfrs[['TEMP_mean', 'PRES_mean']], maxlag=15);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=30.6231 , p=0.0000  , df_denom=1457, df_num=1
# ssr based chi2 test:   chi2=30.6862 , p=0.0000  , df=1
# likelihood ratio test: chi2=30.3681 , p=0.0000  , df=1
# parameter F test:         F=30.6231 , p=0.0000  , df_denom=1457, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=66.0723 , p=0.0000  , df_denom=1454, df_num=2
# ssr based chi2 test:   chi2=132.5990, p=0.0000  , df=2
# likelihood ratio test: chi2=126.9154, p=0.0000  , df=2
# parameter F test:         F=66.0723 , p=0.0000  , df_denom=1454, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=42.9082 , p=0.0000  , df_denom=1451, df_num=3
# ssr based chi2 test:   chi2=129.3455, p=0.0000  , df=3
# likelihood ratio test: chi2=123.9263, p=0.0000  , df=3
# parameter F test:         F=42.9082 , p=0.0000  , df_denom=1451, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=33.1533 , p=0.0000  , df_denom=1448, df_num=4
# ssr based chi2 test:   chi2=133.4374, p=0.0000  , df=4
# likelihood ratio test: chi2=127.6763, p=0.0000  , df=4
# parameter F test:         F=33.1533 , p=0.0000  , df_denom=1448, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=25.5197 , p=0.0000  , df_denom=1445, df_num=5
# ssr based chi2 test:   chi2=128.5698, p=0.0000  , df=5
# likelihood ratio test: chi2=123.2068, p=0.0000  , df=5
# parameter F test:         F=25.5197 , p=0.0000  , df_denom=1445, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=21.4309 , p=0.0000  , df_denom=1442, df_num=6
# ssr based chi2 test:   chi2=129.7448, p=0.0000  , df=6
# likelihood ratio test: chi2=124.2824, p=0.0000  , df=6
# parameter F test:         F=21.4309 , p=0.0000  , df_denom=1442, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=18.7444 , p=0.0000  , df_denom=1439, df_num=7
# ssr based chi2 test:   chi2=132.5783, p=0.0000  , df=7
# likelihood ratio test: chi2=126.8780, p=0.0000  , df=7
# parameter F test:         F=18.7444 , p=0.0000  , df_denom=1439, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=17.3953 , p=0.0000  , df_denom=1436, df_num=8
# ssr based chi2 test:   chi2=140.8096, p=0.0000  , df=8
# likelihood ratio test: chi2=134.3977, p=0.0000  , df=8
# parameter F test:         F=17.3953 , p=0.0000  , df_denom=1436, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=15.8151 , p=0.0000  , df_denom=1433, df_num=9
# ssr based chi2 test:   chi2=144.2231, p=0.0000  , df=9
# likelihood ratio test: chi2=137.5020, p=0.0000  , df=9
# parameter F test:         F=15.8151 , p=0.0000  , df_denom=1433, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=14.5059 , p=0.0000  , df_denom=1430, df_num=10
# ssr based chi2 test:   chi2=147.1888, p=0.0000  , df=10
# likelihood ratio test: chi2=140.1927, p=0.0000  , df=10
# parameter F test:         F=14.5059 , p=0.0000  , df_denom=1430, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=13.3574 , p=0.0000  , df_denom=1427, df_num=11
# ssr based chi2 test:   chi2=149.2998, p=0.0000  , df=11
# likelihood ratio test: chi2=142.1034, p=0.0000  , df=11
# parameter F test:         F=13.3574 , p=0.0000  , df_denom=1427, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=12.3601 , p=0.0000  , df_denom=1424, df_num=12
# ssr based chi2 test:   chi2=150.9251, p=0.0000  , df=12
# likelihood ratio test: chi2=143.5715, p=0.0000  , df=12
# parameter F test:         F=12.3601 , p=0.0000  , df_denom=1424, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=11.5803 , p=0.0000  , df_denom=1421, df_num=13
# ssr based chi2 test:   chi2=153.4046, p=0.0000  , df=13
# likelihood ratio test: chi2=145.8104, p=0.0000  , df=13
# parameter F test:         F=11.5803 , p=0.0000  , df_denom=1421, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=10.9444 , p=0.0000  , df_denom=1418, df_num=14
# ssr based chi2 test:   chi2=156.3555, p=0.0000  , df=14
# likelihood ratio test: chi2=148.4711, p=0.0000  , df=14
# parameter F test:         F=10.9444 , p=0.0000  , df_denom=1418, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=10.4894 , p=0.0000  , df_denom=1415, df_num=15
# ssr based chi2 test:   chi2=160.7874, p=0.0000  , df=15
# likelihood ratio test: chi2=152.4600, p=0.0000  , df=15
# parameter F test:         F=10.4894 , p=0.0000  , df_denom=1415, df_num=15

# %%
grangercausalitytests(dfrs[['TEMP_mean', 'RAIN_sum']], maxlag=15);
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.3601  , p=0.0118  , df_denom=1457, df_num=1
# ssr based chi2 test:   chi2=6.3732  , p=0.0116  , df=1
# likelihood ratio test: chi2=6.3593  , p=0.0117  , df=1
# parameter F test:         F=6.3601  , p=0.0118  , df_denom=1457, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.8424 , p=0.0000  , df_denom=1454, df_num=2
# ssr based chi2 test:   chi2=21.7594 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.5988 , p=0.0000  , df=2
# parameter F test:         F=10.8424 , p=0.0000  , df_denom=1454, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.4748  , p=0.0039  , df_denom=1451, df_num=3
# ssr based chi2 test:   chi2=13.4891 , p=0.0037  , df=3
# likelihood ratio test: chi2=13.4271 , p=0.0038  , df=3
# parameter F test:         F=4.4748  , p=0.0039  , df_denom=1451, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.2847  , p=0.0109  , df_denom=1448, df_num=4
# ssr based chi2 test:   chi2=13.2205 , p=0.0102  , df=4
# likelihood ratio test: chi2=13.1609 , p=0.0105  , df=4
# parameter F test:         F=3.2847  , p=0.0109  , df_denom=1448, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.1988  , p=0.0521  , df_denom=1445, df_num=5
# ssr based chi2 test:   chi2=11.0775 , p=0.0499  , df=5
# likelihood ratio test: chi2=11.0356 , p=0.0507  , df=5
# parameter F test:         F=2.1988  , p=0.0521  , df_denom=1445, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3994  , p=0.0260  , df_denom=1442, df_num=6
# ssr based chi2 test:   chi2=14.5260 , p=0.0243  , df=6
# likelihood ratio test: chi2=14.4540 , p=0.0250  , df=6
# parameter F test:         F=2.3994  , p=0.0260  , df_denom=1442, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8521  , p=0.0739  , df_denom=1439, df_num=7
# ssr based chi2 test:   chi2=13.0997 , p=0.0697  , df=7
# likelihood ratio test: chi2=13.0410 , p=0.0711  , df=7
# parameter F test:         F=1.8521  , p=0.0739  , df_denom=1439, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6137  , p=0.1161  , df_denom=1436, df_num=8
# ssr based chi2 test:   chi2=13.0625 , p=0.1097  , df=8
# likelihood ratio test: chi2=13.0042 , p=0.1117  , df=8
# parameter F test:         F=1.6137  , p=0.1161  , df_denom=1436, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5699  , p=0.1190  , df_denom=1433, df_num=9
# ssr based chi2 test:   chi2=14.3169 , p=0.1115  , df=9
# likelihood ratio test: chi2=14.2468 , p=0.1138  , df=9
# parameter F test:         F=1.5699  , p=0.1190  , df_denom=1433, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4969  , p=0.1345  , df_denom=1430, df_num=10
# ssr based chi2 test:   chi2=15.1890 , p=0.1253  , df=10
# likelihood ratio test: chi2=15.1101 , p=0.1281  , df=10
# parameter F test:         F=1.4969  , p=0.1345  , df_denom=1430, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4275  , p=0.1540  , df_denom=1427, df_num=11
# ssr based chi2 test:   chi2=15.9558 , p=0.1428  , df=11
# likelihood ratio test: chi2=15.8687 , p=0.1461  , df=11
# parameter F test:         F=1.4275  , p=0.1540  , df_denom=1427, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.5571  , p=0.0979  , df_denom=1424, df_num=12
# ssr based chi2 test:   chi2=19.0137 , p=0.0882  , df=12
# likelihood ratio test: chi2=18.8900 , p=0.0912  , df=12
# parameter F test:         F=1.5571  , p=0.0979  , df_denom=1424, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.4745  , p=0.1196  , df_denom=1421, df_num=13
# ssr based chi2 test:   chi2=19.5322 , p=0.1075  , df=13
# likelihood ratio test: chi2=19.4017 , p=0.1112  , df=13
# parameter F test:         F=1.4745  , p=0.1196  , df_denom=1421, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.4547  , p=0.1208  , df_denom=1418, df_num=14
# ssr based chi2 test:   chi2=20.7821 , p=0.1073  , df=14
# likelihood ratio test: chi2=20.6342 , p=0.1114  , df=14
# parameter F test:         F=1.4547  , p=0.1208  , df_denom=1418, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.3389  , p=0.1706  , df_denom=1415, df_num=15
# ssr based chi2 test:   chi2=20.5235 , p=0.1528  , df=15
# likelihood ratio test: chi2=20.3792 , p=0.1579  , df=15
# parameter F test:         F=1.3389  , p=0.1706  , df_denom=1415, df_num=15
